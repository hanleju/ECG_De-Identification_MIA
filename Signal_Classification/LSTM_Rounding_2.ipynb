# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import csv
import pywt
from scipy import stats

from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # matplotlib Settings

# %%
plt.rcParams["figure.figsize"] = (30,6)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Methods Definitions

# %%
def denoise(data): 
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))
        
    datarec = pywt.waverec(coeffs, 'sym4')
    
    return datarec

# %% [markdown]
# # Variables Definitions

# %%
path = 'mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# %% [markdown]
# # Prepere Input Files

# %%
# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt 
records = list()
annotations = list()
filenames.sort()

# %%
# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)
    
    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
def rounding(signals, round):
    signals = np.round(signals,round)
    return signals

# %% [markdown]
# # Data Extraction and Preprocessing

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1
            
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()
    
    ### rounding 
    round = 2
    signals = rounding(signals,round)
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after rounding ")
        plt.plot(signals[0:200])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()



    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines() 
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat    
                    if r is 1 and not example_beat_printed: 
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:31: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:68: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:31: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:68: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\root\AppData\Local\Temp\ipykernel_17740\3587129702.py:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# C:\Users\root\AppData\Local\Temp\ipykernel_17740\3587129702.py:22: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# C:\Users\root\AppData\Local\Temp\ipykernel_17740\3587129702.py:31: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# C:\Users\root\AppData\Local\Temp\ipykernel_17740\3587129702.py:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1:
# C:\Users\root\AppData\Local\Temp\ipykernel_17740\3587129702.py:68: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if r is 1 and not example_beat_printed:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])
#         X[i].append(y[i])

print(np.shape(X))
# Out:
# (100012, 361)

# %% [markdown]
# # Classes Distribution

# %%
X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 360
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: count, dtype: int64

# %% [markdown]
# # Train-Test Split

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))
# Out:
# X_train :  (20000, 361)
# X_test  :  (5000, 361)

# %%
target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))
# Out:
# (20000, 5) (5000, 5)

# %%
train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# (20000, 360, 1) (5000, 360, 1)

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(LSTM(32, return_sequences=True, activation='tanh', input_shape=(360,1)))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(32,activation='relu'))
model.add(Dense(5,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 360, 32)           4352
#
#  lstm_1 (LSTM)               (None, 360, 64)           24832
#
#  lstm_2 (LSTM)               (None, 360, 64)           33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 97477 (380.77 KB)
# Trainable params: 97477 (380.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
history = model.fit(train_x, train_y, batch_size=36, epochs=25, verbose=1, validation_data=(test_x, test_y))
# Out:
# Epoch 1/25
# 556/556 [==============================] - 157s 275ms/step - loss: 1.4406 - accuracy: 0.3674 - val_loss: 1.5023 - val_accuracy: 0.3482
# Epoch 2/25
# 556/556 [==============================] - 151s 272ms/step - loss: 1.3173 - accuracy: 0.4568 - val_loss: 1.2382 - val_accuracy: 0.5088
# Epoch 3/25
# 556/556 [==============================] - 158s 285ms/step - loss: 1.0903 - accuracy: 0.5917 - val_loss: 1.0270 - val_accuracy: 0.6172
# Epoch 4/25
# 556/556 [==============================] - 158s 285ms/step - loss: 0.9794 - accuracy: 0.6385 - val_loss: 0.9021 - val_accuracy: 0.6720
# Epoch 5/25
# 556/556 [==============================] - 158s 283ms/step - loss: 0.7908 - accuracy: 0.7161 - val_loss: 0.6933 - val_accuracy: 0.7522
# Epoch 6/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.7689 - accuracy: 0.7179 - val_loss: 0.6623 - val_accuracy: 0.7538
# Epoch 7/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.6914 - accuracy: 0.7461 - val_loss: 0.6702 - val_accuracy: 0.7504
# Epoch 8/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.6382 - accuracy: 0.7676 - val_loss: 0.6111 - val_accuracy: 0.7716
# Epoch 9/25
# 556/556 [==============================] - 157s 282ms/step - loss: 0.7033 - accuracy: 0.7430 - val_loss: 1.3471 - val_accuracy: 0.4612
# Epoch 10/25
# 556/556 [==============================] - 157s 283ms/step - loss: 0.9585 - accuracy: 0.6403 - val_loss: 0.8998 - val_accuracy: 0.6516
# Epoch 11/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.9118 - accuracy: 0.6518 - val_loss: 1.3621 - val_accuracy: 0.4278
# Epoch 12/25
# 556/556 [==============================] - 158s 283ms/step - loss: 1.2234 - accuracy: 0.5149 - val_loss: 1.1253 - val_accuracy: 0.5768
# Epoch 13/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.9869 - accuracy: 0.6353 - val_loss: 0.8218 - val_accuracy: 0.7022
# Epoch 14/25
# 556/556 [==============================] - 158s 283ms/step - loss: 0.7026 - accuracy: 0.7469 - val_loss: 0.5780 - val_accuracy: 0.7912
# Epoch 15/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.5373 - accuracy: 0.8079 - val_loss: 0.4865 - val_accuracy: 0.8306
# Epoch 16/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.4346 - accuracy: 0.8443 - val_loss: 0.3812 - val_accuracy: 0.8618
# Epoch 17/25
# 556/556 [==============================] - 158s 284ms/step - loss: 0.4108 - accuracy: 0.8522 - val_loss: 1.4959 - val_accuracy: 0.4650
# Epoch 18/25
# 556/556 [==============================] - 158s 284ms/step - loss: 1.1566 - accuracy: 0.5552 - val_loss: 1.0143 - val_accuracy: 0.6042
# Epoch 19/25
# 556/556 [==============================] - 157s 283ms/step - loss: 0.8684 - accuracy: 0.6713 - val_loss: 0.5885 - val_accuracy: 0.7960
# Epoch 20/25
# 556/556 [==============================] - 157s 283ms/step - loss: 0.4374 - accuracy: 0.8438 - val_loss: 0.3261 - val_accuracy: 0.8892
# Epoch 21/25
# 556/556 [==============================] - 158s 283ms/step - loss: 0.3143 - accuracy: 0.8903 - val_loss: 0.2752 - val_accuracy: 0.9074
# Epoch 22/25
# 556/556 [==============================] - 157s 282ms/step - loss: 0.2522 - accuracy: 0.9115 - val_loss: 0.3574 - val_accuracy: 0.8840
# Epoch 23/25
# 556/556 [==============================] - 157s 283ms/step - loss: 0.2311 - accuracy: 0.9233 - val_loss: 0.2256 - val_accuracy: 0.9234
# Epoch 24/25
# 556/556 [==============================] - 157s 283ms/step - loss: 0.1878 - accuracy: 0.9362 - val_loss: 0.1588 - val_accuracy: 0.9456
# Epoch 25/25
# 556/556 [==============================] - 157s 282ms/step - loss: 0.1696 - accuracy: 0.9433 - val_loss: 0.1610 - val_accuracy: 0.9416

# %% [markdown]
# **Plotting the loss convergence**

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Plotting accuracy**

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test

# %%
score = model.evaluate(test_x, test_y)

print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 157/157 [==============================] - 13s 85ms/step - loss: 0.1610 - accuracy: 0.9416
# Test Loss: 0.16102860867977142
# Test accuracy: 0.9416000247001648

# %%
model.save('model_rounding2.h5')
# Out:
# C:\Users\root\AppData\Roaming\Python\Python38\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
