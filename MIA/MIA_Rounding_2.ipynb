# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15164509904725732348
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14626652160
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1289916903673237045
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
#!pip install tensorflow-privacy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os
import csv
import pywt
from scipy import stats, special
import matplotlib.pyplot as plt

path = ''

import tensorflow as tf

from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import to_categorical

# privacy package
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.optimizers import Adam

# set random seed
import random
random.seed(19122)
from keras.layers import LSTM
# set random seed
np.random.seed(19122)
tf.random.set_seed(19122)

tf.compat.v1.enable_eager_execution()
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackResultsCollection
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyMetric
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyReportMetadata
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import privacy_report

import warnings
warnings.filterwarnings("ignore")

# %%
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/RIS/MIT
# Out:
# /content/drive/MyDrive/Colab Notebooks/RIS/MIT

# %% [markdown]
# ## Data

# %%
def denoise(data):
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))

    datarec = pywt.waverec(coeffs, 'sym4')

    return datarec

path = 'mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt
records = list()
annotations = list()
filenames.sort()

# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)

    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
def rounding(signals, round):
    signals = np.round(signals,round)
    return signals

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1

    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:700])
        plt.show()

    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()

    ### rounding
    round = 2
    signals = rounding(signals,round)
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after rounding ")
        plt.plot(signals[0:200])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()



    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines()
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat
                    if r is 1 and not example_beat_printed:
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])

print(np.shape(X))

X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# (100012, 361)
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))

target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))

train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# X_train :  (80009, 361)
# X_test  :  (20003, 361)
# (80009, 5) (20003, 5)
# (80009, 360, 1) (20003, 360, 1)

# %% [markdown]
# ## PrivacyMetric

# %%
class PrivacyMetrics(tf.keras.callbacks.Callback):
  def __init__(self, epochs_per_report, model_name):
    self.epochs_per_report = epochs_per_report
    self.model_name = model_name
    self.attack_results = []

  def on_epoch_end(self, epoch, logs=None):
    epoch = epoch+1

    if epoch % self.epochs_per_report != 0:
      return

    print(f'\nRunning privacy report for epoch: {epoch}\n')

    print('Predict on train...')
    logits_train = model.predict(train_x, batch_size=batch_size)
    print('Predict on test...')
    logits_test = model.predict(test_x, batch_size=batch_size)

    print('Apply softmax to get probabilities from logits...')
    prob_train = tf.nn.softmax(logits_train, axis=-1)
    prob_test = tf.nn.softmax(logits_test)

    print('Compute losses...')
    cce = tf.keras.backend.categorical_crossentropy
    constant = tf.keras.backend.constant

    y_train_onehot = to_categorical(train_y)
    y_test_onehot = to_categorical(test_y)

    prob_train_onehot = to_categorical(prob_train)
    prob_test_onehot = to_categorical(prob_test)

    loss_train = cce(constant(train_y), constant(prob_train), from_logits=False).numpy()
    loss_test = cce(constant(test_y), constant(prob_test), from_logits=False).numpy()

    print("Add metadata")
    # Add metadata to generate a privacy report.
    privacy_report_metadata = PrivacyReportMetadata(
        # Show the validation accuracy on the plot
        # It's what you send to train_accuracy that gets plotted.
        accuracy_train=logs['val_accuracy'],
        accuracy_test=logs['val_accuracy'],
        epoch_num=epoch,
        model_variant_label=self.model_name)

    print("Start AttackInputData")
    attack_input = AttackInputData(
      logits_train = logits_train,
      logits_test = logits_test,
      loss_train = loss_train,
      loss_test = loss_test,
      labels_train = np.argmax(train_y, axis=1),
      labels_test = np.argmax(test_y, axis=1)
    )
    print("Start SlicingSpec")
    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
    by_classification_correctness = True)
    print("Start attack_types")
    attack_types = [
        AttackType.THRESHOLD_ENTROPY_ATTACK,
        AttackType.MULTI_LAYERED_PERCEPTRON,
    ]
    print("Start Run Attacks")
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                    slicing_spec=slicing_spec,
                                    attack_types=attack_types,
                                    privacy_report_metadata=privacy_report_metadata
                                    )


    self.attack_results.append(attacks_result)

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(LSTM(32, return_sequences=True, activation='tanh', input_shape=(360,1)))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(32,activation='relu'))
model.add(Dense(5,activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'], run_eagerly=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 360, 32)           4352
#
#  lstm_1 (LSTM)               (None, 360, 64)           24832
#
#  lstm_2 (LSTM)               (None, 360, 64)           33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 97477 (380.77 KB)
# Trainable params: 97477 (380.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
epochs_per_report = 1
batch_size = 512
callback = PrivacyMetrics(epochs_per_report, "sequential_2")

all_reports = []

history = model.fit(
      train_x,
      train_y,
      batch_size=batch_size,
      epochs=25,
      validation_data=(test_x, test_y),
      callbacks=[callback],
      shuffle=True)

all_reports.extend(callback.attack_results)
# Out:
# Epoch 1/25
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7bf7245acb80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7bf7245acb80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 157/157 [==============================] - ETA: 0s - loss: 0.9334 - accuracy: 0.7456
# Running privacy report for epoch: 1
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 51ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 140s 881ms/step - loss: 0.9334 - accuracy: 0.7456 - val_loss: 0.9104 - val_accuracy: 0.7433
# Epoch 2/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8831 - accuracy: 0.7517
# Running privacy report for epoch: 2
#
# Predict on train...
# 157/157 [==============================] - 7s 42ms/step
# Predict on test...
# 40/40 [==============================] - 2s 55ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 138s 882ms/step - loss: 0.8831 - accuracy: 0.7517 - val_loss: 0.8654 - val_accuracy: 0.7433
# Epoch 3/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8269 - accuracy: 0.7567
# Running privacy report for epoch: 3
#
# Predict on train...
# 157/157 [==============================] - 7s 42ms/step
# Predict on test...
# 40/40 [==============================] - 2s 44ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 151s 970ms/step - loss: 0.8269 - accuracy: 0.7567 - val_loss: 0.6409 - val_accuracy: 0.8075
# Epoch 4/25
# 157/157 [==============================] - ETA: 0s - loss: 0.5464 - accuracy: 0.8445
# Running privacy report for epoch: 4
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 167s 1s/step - loss: 0.5464 - accuracy: 0.8445 - val_loss: 0.4807 - val_accuracy: 0.8663
# Epoch 5/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3810 - accuracy: 0.8913
# Running privacy report for epoch: 5
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 172s 1s/step - loss: 0.3810 - accuracy: 0.8913 - val_loss: 0.2938 - val_accuracy: 0.9182
# Epoch 6/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2651 - accuracy: 0.9276
# Running privacy report for epoch: 6
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 165s 1s/step - loss: 0.2651 - accuracy: 0.9276 - val_loss: 0.2287 - val_accuracy: 0.9397
# Epoch 7/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9402
# Running privacy report for epoch: 7
#
# Predict on train...
# 157/157 [==============================] - 7s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 163s 1s/step - loss: 0.2269 - accuracy: 0.9402 - val_loss: 0.2012 - val_accuracy: 0.9479
# Epoch 8/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9567
# Running privacy report for epoch: 8
#
# Predict on train...
# 157/157 [==============================] - 7s 42ms/step
# Predict on test...
# 40/40 [==============================] - 2s 56ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 166s 1s/step - loss: 0.1709 - accuracy: 0.9567 - val_loss: 0.1643 - val_accuracy: 0.9589
# Epoch 9/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9644
# Running privacy report for epoch: 9
#
# Predict on train...
# 157/157 [==============================] - 7s 46ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 160s 1s/step - loss: 0.1421 - accuracy: 0.9644 - val_loss: 0.1716 - val_accuracy: 0.9562
# Epoch 10/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9686
# Running privacy report for epoch: 10
#
# Predict on train...
# 157/157 [==============================] - 7s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 46ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 161s 1s/step - loss: 0.1260 - accuracy: 0.9686 - val_loss: 0.2003 - val_accuracy: 0.9472
# Epoch 11/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9710
# Running privacy report for epoch: 11
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 156s 1s/step - loss: 0.1147 - accuracy: 0.9710 - val_loss: 0.1121 - val_accuracy: 0.9732
# Epoch 12/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9757
# Running privacy report for epoch: 12
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 152s 972ms/step - loss: 0.0929 - accuracy: 0.9757 - val_loss: 0.1002 - val_accuracy: 0.9747
# Epoch 13/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9778
# Running privacy report for epoch: 13
#
# Predict on train...
# 157/157 [==============================] - 7s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 155s 992ms/step - loss: 0.0817 - accuracy: 0.9778 - val_loss: 0.1039 - val_accuracy: 0.9703
# Epoch 14/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9797
# Running privacy report for epoch: 14
#
# Predict on train...
# 157/157 [==============================] - 7s 43ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 154s 984ms/step - loss: 0.0737 - accuracy: 0.9797 - val_loss: 0.0808 - val_accuracy: 0.9775
# Epoch 15/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9811
# Running privacy report for epoch: 15
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 55ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 161s 1s/step - loss: 0.0692 - accuracy: 0.9811 - val_loss: 0.0839 - val_accuracy: 0.9771
# Epoch 16/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9805
# Running privacy report for epoch: 16
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 44ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 168s 1s/step - loss: 0.0726 - accuracy: 0.9805 - val_loss: 0.0776 - val_accuracy: 0.9794
# Epoch 17/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9831
# Running privacy report for epoch: 17
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 44ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 167s 1s/step - loss: 0.0626 - accuracy: 0.9831 - val_loss: 0.0727 - val_accuracy: 0.9808
# Epoch 18/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9838
# Running privacy report for epoch: 18
#
# Predict on train...
# 157/157 [==============================] - 7s 44ms/step
# Predict on test...
# 40/40 [==============================] - 2s 55ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 155s 994ms/step - loss: 0.0594 - accuracy: 0.9838 - val_loss: 0.0641 - val_accuracy: 0.9834
# Epoch 19/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9850
# Running privacy report for epoch: 19
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 158s 1s/step - loss: 0.0555 - accuracy: 0.9850 - val_loss: 0.0671 - val_accuracy: 0.9818
# Epoch 20/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9857
# Running privacy report for epoch: 20
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 154s 988ms/step - loss: 0.0519 - accuracy: 0.9857 - val_loss: 0.0645 - val_accuracy: 0.9838
# Epoch 21/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9870
# Running privacy report for epoch: 21
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 160s 1s/step - loss: 0.0472 - accuracy: 0.9870 - val_loss: 0.0596 - val_accuracy: 0.9838
# Epoch 22/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9876
# Running privacy report for epoch: 22
#
# Predict on train...
# 157/157 [==============================] - 7s 43ms/step
# Predict on test...
# 40/40 [==============================] - 2s 53ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 161s 1s/step - loss: 0.0458 - accuracy: 0.9876 - val_loss: 0.0606 - val_accuracy: 0.9829
# Epoch 23/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9875
# Running privacy report for epoch: 23
#
# Predict on train...
# 157/157 [==============================] - 7s 42ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 151s 964ms/step - loss: 0.0454 - accuracy: 0.9875 - val_loss: 0.0620 - val_accuracy: 0.9838
# Epoch 24/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9875
# Running privacy report for epoch: 24
#
# Predict on train...
# 157/157 [==============================] - 7s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 154s 987ms/step - loss: 0.0457 - accuracy: 0.9875 - val_loss: 0.0537 - val_accuracy: 0.9860
# Epoch 25/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9888
# Running privacy report for epoch: 25
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 160s 1s/step - loss: 0.0413 - accuracy: 0.9888 - val_loss: 0.0516 - val_accuracy: 0.9869

# %%
results = AttackResultsCollection(all_reports)

# %% [markdown]
# ## Evaluate

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
epoch_plot = privacy_report.plot_by_epochs(
    results, privacy_metrics=privacy_metrics)

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
utility_privacy_plot = privacy_report.plot_privacy_vs_accuracy(
    results, privacy_metrics=privacy_metrics)

for axis in utility_privacy_plot.axes:
  axis.set_xlabel('Validation accuracy')

# %% [markdown]
# ## Evaluate2

# %%
print(all_reports[-1].summary(by_slices=True))
# Out:
# Best-performing attacks over all slices
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an AUC of 0.67 on slice CLASS=1
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an advantage of 0.35 on slice CLASS=1
#   THRESHOLD_ENTROPY_ATTACK (with 6397 training and 1674 test examples) achieved a positive predictive value of 1.00 on slice CLASS=1
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved top-5 epsilon lower bounds of 1.7311, 1.5915, 1.5912, 1.5840, 1.5175 on slice CLASS=2
#
# Best-performing attacks over slice: "Entire dataset"
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an AUC of 0.65
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an advantage of 0.32
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved a positive predictive value of 0.90
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved top-5 epsilon lower bounds of 1.4671, 1.4556, 1.4499, 1.4456, 1.4415
#
# Best-performing attacks over slice: "CLASS=0"
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved an AUC of 0.67
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved an advantage of 0.35
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved top-5 epsilon lower bounds of 1.6641, 1.5281, 1.4885, 1.4699, 1.4411
#
# Best-performing attacks over slice: "CLASS=1"
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an AUC of 0.67
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an advantage of 0.35
#   THRESHOLD_ENTROPY_ATTACK (with 6397 training and 1674 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved top-5 epsilon lower bounds of 1.1389, 1.1377, 1.1375, 1.1370, 1.1365
#
# Best-performing attacks over slice: "CLASS=2"
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved an AUC of 0.64
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved an advantage of 0.32
#   THRESHOLD_ENTROPY_ATTACK (with 5803 training and 1452 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved top-5 epsilon lower bounds of 1.7311, 1.5915, 1.5912, 1.5840, 1.5175
#
# Best-performing attacks over slice: "CLASS=3"
#   THRESHOLD_ENTROPY_ATTACK (with 1992 training and 554 test examples) achieved an AUC of 0.53
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved an advantage of 0.23
#   THRESHOLD_ENTROPY_ATTACK (with 1992 training and 554 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved top-5 epsilon lower bounds of 1.6925, 1.6506, 1.5920, 1.4880, 1.4878
#
# Best-performing attacks over slice: "CLASS=4"
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved an AUC of 0.65
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved an advantage of 0.32
#   THRESHOLD_ENTROPY_ATTACK (with 5674 training and 1455 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved top-5 epsilon lower bounds of 1.1390, 1.1158, 1.1063, 1.1063, 1.1047
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   THRESHOLD_ENTROPY_ATTACK (with 79253 training and 19740 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 79253 training and 19740 test examples) achieved an advantage of 0.26
#   MULTI_LAYERED_PERCEPTRON (with 79253 training and 19740 test examples) achieved a positive predictive value of 0.89
#   MULTI_LAYERED_PERCEPTRON (with 79253 training and 19740 test examples) achieved top-5 epsilon lower bounds of 1.3390, 1.3390, 1.3380, 1.3379, 1.3379
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   THRESHOLD_ENTROPY_ATTACK (with 756 training and 263 test examples) achieved an AUC of 0.58
#   THRESHOLD_ENTROPY_ATTACK (with 756 training and 263 test examples) achieved an advantage of 0.15
#   THRESHOLD_ENTROPY_ATTACK (with 756 training and 263 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 756 training and 263 test examples) achieved top-5 epsilon lower bounds of 0.4931, 0.4824, 0.4758, 0.4747, 0.4719

# %%
import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
plotting.plot_roc_curve(all_reports[-1].get_result_with_max_auc().roc_curve)
