# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12122939365232770750
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14626652160
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10804461692788828909
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
#!pip install tensorflow-privacy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os
import csv
import pywt
from scipy import stats, special
import matplotlib.pyplot as plt

path = ''

import tensorflow as tf

from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import to_categorical

# privacy package
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.optimizers import Adam

# set random seed
import random
random.seed(19122)
from keras.layers import LSTM
# set random seed
np.random.seed(19122)
tf.random.set_seed(19122)

tf.compat.v1.enable_eager_execution()
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackResultsCollection
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyMetric
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyReportMetadata
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import privacy_report

import warnings
warnings.filterwarnings("ignore")

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/RIS/MIT
# Out:
# /content/drive/MyDrive/Colab Notebooks/RIS/MIT

# %% [markdown]
# ## Data

# %%
def denoise(data):
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))

    datarec = pywt.waverec(coeffs, 'sym4')

    return datarec

path = 'mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt
records = list()
annotations = list()
filenames.sort()

# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)

    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1

    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:200])
        plt.show()

    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:200])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:200])
        plt.show()

    # 싸이너스 노이즈 파형을 생성합니다.
    frequency = 10  # 노이즈 주파수 = 높은 주파수는 빠르게 = 속도 결정
    amplitude = 1  # 노이즈 진폭 = 노이즈의 크기
    phase = 0  # 노이즈 위상 = 파형의 시작점
    t = np.arange(0, len(signals)/100 ,0.01)


    sinusoid_noise = amplitude * np.sin(2 * np.pi * frequency * t + phase)

    # 원본 ECG 데이터에 싸이너스 노이즈를 추가합니다.
    signals = signals + sinusoid_noise

    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after add sinusoid noise ")
        plt.plot(signals[0:200])
        plt.show()

    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines()
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat
                    if r is 1 and not example_beat_printed:
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])

print(np.shape(X))

X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# (100012, 361)
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))

target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))

train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# X_train :  (80009, 361)
# X_test  :  (20003, 361)
# (80009, 5) (20003, 5)
# (80009, 360, 1) (20003, 360, 1)

# %% [markdown]
# ## PrivacyMetric

# %%
class PrivacyMetrics(tf.keras.callbacks.Callback):
  def __init__(self, epochs_per_report, model_name):
    self.epochs_per_report = epochs_per_report
    self.model_name = model_name
    self.attack_results = []

  def on_epoch_end(self, epoch, logs=None):
    epoch = epoch+1

    if epoch % self.epochs_per_report != 0:
      return

    print(f'\nRunning privacy report for epoch: {epoch}\n')

    print('Predict on train...')
    logits_train = model.predict(train_x, batch_size=batch_size)
    print('Predict on test...')
    logits_test = model.predict(test_x, batch_size=batch_size)

    print('Apply softmax to get probabilities from logits...')
    prob_train = tf.nn.softmax(logits_train, axis=-1)
    prob_test = tf.nn.softmax(logits_test)

    print('Compute losses...')
    cce = tf.keras.backend.categorical_crossentropy
    constant = tf.keras.backend.constant

    y_train_onehot = to_categorical(train_y)
    y_test_onehot = to_categorical(test_y)

    prob_train_onehot = to_categorical(prob_train)
    prob_test_onehot = to_categorical(prob_test)

    loss_train = cce(constant(train_y), constant(prob_train), from_logits=False).numpy()
    loss_test = cce(constant(test_y), constant(prob_test), from_logits=False).numpy()

    print("Add metadata")
    # Add metadata to generate a privacy report.
    privacy_report_metadata = PrivacyReportMetadata(
        # Show the validation accuracy on the plot
        # It's what you send to train_accuracy that gets plotted.
        accuracy_train=logs['val_accuracy'],
        accuracy_test=logs['val_accuracy'],
        epoch_num=epoch,
        model_variant_label=self.model_name)

    print("Start AttackInputData")
    attack_input = AttackInputData(
      logits_train = logits_train,
      logits_test = logits_test,
      loss_train = loss_train,
      loss_test = loss_test,
      labels_train = np.argmax(train_y, axis=1),
      labels_test = np.argmax(test_y, axis=1)
    )
    print("Start SlicingSpec")
    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
    by_classification_correctness = True)
    print("Start attack_types")
    attack_types = [
        AttackType.THRESHOLD_ENTROPY_ATTACK,
        AttackType.MULTI_LAYERED_PERCEPTRON,
    ]
    print("Start Run Attacks")
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                    slicing_spec=slicing_spec,
                                    attack_types=attack_types,
                                    privacy_report_metadata=privacy_report_metadata
                                    )


    self.attack_results.append(attacks_result)

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(LSTM(32, return_sequences=True, activation='tanh', input_shape=(360,1)))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(32,activation='relu'))
model.add(Dense(5,activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'], run_eagerly=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 360, 32)           4352
#
#  lstm_1 (LSTM)               (None, 360, 64)           24832
#
#  lstm_2 (LSTM)               (None, 360, 64)           33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 97477 (380.77 KB)
# Trainable params: 97477 (380.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
epochs_per_report = 1
batch_size = 512
callback = PrivacyMetrics(epochs_per_report, "sequential_2")

all_reports = []

history = model.fit(
      train_x,
      train_y,
      batch_size=batch_size,
      epochs=25,
      validation_data=(test_x, test_y),
      callbacks=[callback],
      shuffle=True)

all_reports.extend(callback.attack_results)
# Out:
# Epoch 1/25
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f0562e757e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f0562e757e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 157/157 [==============================] - ETA: 0s - loss: 0.9272 - accuracy: 0.7454
# Running privacy report for epoch: 1
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 51ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 149s 932ms/step - loss: 0.9272 - accuracy: 0.7454 - val_loss: 0.8985 - val_accuracy: 0.7451
# Epoch 2/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8773 - accuracy: 0.7517
# Running privacy report for epoch: 2
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 153s 979ms/step - loss: 0.8773 - accuracy: 0.7517 - val_loss: 0.8989 - val_accuracy: 0.7433
# Epoch 3/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8771 - accuracy: 0.7515
# Running privacy report for epoch: 3
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 143s 914ms/step - loss: 0.8771 - accuracy: 0.7515 - val_loss: 0.9001 - val_accuracy: 0.7451
# Epoch 4/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8772 - accuracy: 0.7518
# Running privacy report for epoch: 4
#
# Predict on train...
# 157/157 [==============================] - 7s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 138s 883ms/step - loss: 0.8772 - accuracy: 0.7518 - val_loss: 0.8973 - val_accuracy: 0.7452
# Epoch 5/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8773 - accuracy: 0.7516
# Running privacy report for epoch: 5
#
# Predict on train...
# 157/157 [==============================] - 7s 42ms/step
# Predict on test...
# 40/40 [==============================] - 2s 54ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 141s 903ms/step - loss: 0.8773 - accuracy: 0.7516 - val_loss: 0.8986 - val_accuracy: 0.7433
# Epoch 6/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8777 - accuracy: 0.7517
# Running privacy report for epoch: 6
#
# Predict on train...
# 157/157 [==============================] - 7s 42ms/step
# Predict on test...
# 40/40 [==============================] - 2s 55ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 141s 900ms/step - loss: 0.8777 - accuracy: 0.7517 - val_loss: 0.8973 - val_accuracy: 0.7453
# Epoch 7/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8773 - accuracy: 0.7517
# Running privacy report for epoch: 7
#
# Predict on train...
# 157/157 [==============================] - 6s 40ms/step
# Predict on test...
# 40/40 [==============================] - 2s 44ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 140s 894ms/step - loss: 0.8773 - accuracy: 0.7517 - val_loss: 0.8980 - val_accuracy: 0.7433
# Epoch 8/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8770 - accuracy: 0.7522
# Running privacy report for epoch: 8
#
# Predict on train...
# 157/157 [==============================] - 6s 40ms/step
# Predict on test...
# 40/40 [==============================] - 2s 54ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 150s 959ms/step - loss: 0.8770 - accuracy: 0.7522 - val_loss: 0.8975 - val_accuracy: 0.7452
# Epoch 9/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8758 - accuracy: 0.7524
# Running privacy report for epoch: 9
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 48ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 142s 906ms/step - loss: 0.8758 - accuracy: 0.7524 - val_loss: 0.8947 - val_accuracy: 0.7450
# Epoch 10/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8685 - accuracy: 0.7514
# Running privacy report for epoch: 10
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 147s 942ms/step - loss: 0.8685 - accuracy: 0.7514 - val_loss: 0.8830 - val_accuracy: 0.7451
# Epoch 11/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8382 - accuracy: 0.7521
# Running privacy report for epoch: 11
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 160s 1s/step - loss: 0.8382 - accuracy: 0.7521 - val_loss: 0.8330 - val_accuracy: 0.7593
# Epoch 12/25
# 157/157 [==============================] - ETA: 0s - loss: 0.6050 - accuracy: 0.8158
# Running privacy report for epoch: 12
#
# Predict on train...
# 157/157 [==============================] - 8s 50ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 165s 1s/step - loss: 0.6050 - accuracy: 0.8158 - val_loss: 0.5634 - val_accuracy: 0.8274
# Epoch 13/25
# 157/157 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.8498
# Running privacy report for epoch: 13
#
# Predict on train...
# 157/157 [==============================] - 6s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 179s 1s/step - loss: 0.5180 - accuracy: 0.8498 - val_loss: 0.4707 - val_accuracy: 0.8657
# Epoch 14/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3902 - accuracy: 0.8827
# Running privacy report for epoch: 14
#
# Predict on train...
# 157/157 [==============================] - 7s 44ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 179s 1s/step - loss: 0.3902 - accuracy: 0.8827 - val_loss: 0.3778 - val_accuracy: 0.8877
# Epoch 15/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.9189
# Running privacy report for epoch: 15
#
# Predict on train...
# 157/157 [==============================] - 6s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 173s 1s/step - loss: 0.2990 - accuracy: 0.9189 - val_loss: 0.3162 - val_accuracy: 0.9160
# Epoch 16/25
# 157/157 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.8262
# Running privacy report for epoch: 16
#
# Predict on train...
# 157/157 [==============================] - 7s 43ms/step
# Predict on test...
# 40/40 [==============================] - 2s 49ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 157s 1s/step - loss: 0.6307 - accuracy: 0.8262 - val_loss: 0.8703 - val_accuracy: 0.7531
# Epoch 17/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8805 - accuracy: 0.7524
# Running privacy report for epoch: 17
#
# Predict on train...
# 157/157 [==============================] - 7s 44ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 143s 915ms/step - loss: 0.8805 - accuracy: 0.7524 - val_loss: 0.8956 - val_accuracy: 0.7433
# Epoch 18/25
# 157/157 [==============================] - ETA: 0s - loss: 0.7813 - accuracy: 0.7685
# Running privacy report for epoch: 18
#
# Predict on train...
# 157/157 [==============================] - 6s 40ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 154s 985ms/step - loss: 0.7813 - accuracy: 0.7685 - val_loss: 0.5867 - val_accuracy: 0.8279
# Epoch 19/25
# 157/157 [==============================] - ETA: 0s - loss: 0.5280 - accuracy: 0.8333
# Running privacy report for epoch: 19
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 167s 1s/step - loss: 0.5280 - accuracy: 0.8333 - val_loss: 0.5180 - val_accuracy: 0.8236
# Epoch 20/25
# 157/157 [==============================] - ETA: 0s - loss: 0.4263 - accuracy: 0.8607
# Running privacy report for epoch: 20
#
# Predict on train...
# 157/157 [==============================] - 6s 40ms/step
# Predict on test...
# 40/40 [==============================] - 2s 45ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 167s 1s/step - loss: 0.4263 - accuracy: 0.8607 - val_loss: 0.3871 - val_accuracy: 0.8746
# Epoch 21/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8988
# Running privacy report for epoch: 21
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 173s 1s/step - loss: 0.3507 - accuracy: 0.8988 - val_loss: 0.5214 - val_accuracy: 0.8526
# Epoch 22/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9179
# Running privacy report for epoch: 22
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 190s 1s/step - loss: 0.3005 - accuracy: 0.9179 - val_loss: 0.2401 - val_accuracy: 0.9374
# Epoch 23/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9432
# Running privacy report for epoch: 23
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 44ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 166s 1s/step - loss: 0.2160 - accuracy: 0.9432 - val_loss: 0.2659 - val_accuracy: 0.9291
# Epoch 24/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9493
# Running privacy report for epoch: 24
#
# Predict on train...
# 157/157 [==============================] - 6s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 57ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 174s 1s/step - loss: 0.1885 - accuracy: 0.9493 - val_loss: 0.1681 - val_accuracy: 0.9570
# Epoch 25/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.9089
# Running privacy report for epoch: 25
#
# Predict on train...
# 157/157 [==============================] - 7s 44ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 175s 1s/step - loss: 0.3292 - accuracy: 0.9089 - val_loss: 0.9337 - val_accuracy: 0.7268

# %%
results = AttackResultsCollection(all_reports)

# %% [markdown]
# ## Evaluate

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
epoch_plot = privacy_report.plot_by_epochs(
    results, privacy_metrics=privacy_metrics)

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
utility_privacy_plot = privacy_report.plot_privacy_vs_accuracy(
    results, privacy_metrics=privacy_metrics)

for axis in utility_privacy_plot.axes:
  axis.set_xlabel('Validation accuracy')

# %% [markdown]
# ## Evaluate2

# %%
print(all_reports[-1].summary(by_slices=True))
# Out:
# Best-performing attacks over all slices
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved an AUC of 0.63 on slice CLASS=0
#   MULTI_LAYERED_PERCEPTRON (with 58500 training and 14538 test examples) achieved an advantage of 0.32 on slice CORRECTLY_CLASSIFIED=True
#   THRESHOLD_ENTROPY_ATTACK (with 5803 training and 1452 test examples) achieved a positive predictive value of 1.00 on slice CLASS=2
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved top-5 epsilon lower bounds of 1.8490, 1.6641, 1.4885, 1.4411, 1.4386 on slice CLASS=0
#
# Best-performing attacks over slice: "Entire dataset"
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an AUC of 0.57
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an advantage of 0.21
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved a positive predictive value of 0.86
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved top-5 epsilon lower bounds of 1.5912, 1.4772, 1.4586, 1.4298, 1.3929
#
# Best-performing attacks over slice: "CLASS=0"
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved an AUC of 0.63
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved an advantage of 0.30
#   THRESHOLD_ENTROPY_ATTACK (with 60143 training and 14868 test examples) achieved a positive predictive value of 0.90
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved top-5 epsilon lower bounds of 1.8490, 1.6641, 1.4885, 1.4411, 1.4386
#
# Best-performing attacks over slice: "CLASS=1"
#   THRESHOLD_ENTROPY_ATTACK (with 6397 training and 1674 test examples) achieved an AUC of 0.51
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an advantage of 0.13
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved a positive predictive value of 0.94
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved top-5 epsilon lower bounds of 0.9566, 0.9274, 0.9200, 0.9121, 0.8934
#
# Best-performing attacks over slice: "CLASS=2"
#   THRESHOLD_ENTROPY_ATTACK (with 5803 training and 1452 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved an advantage of 0.23
#   THRESHOLD_ENTROPY_ATTACK (with 5803 training and 1452 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved top-5 epsilon lower bounds of 1.1267, 1.1192, 1.1158, 1.1140, 1.1087
#
# Best-performing attacks over slice: "CLASS=3"
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved an AUC of 0.53
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved an advantage of 0.19
#   THRESHOLD_ENTROPY_ATTACK (with 1992 training and 554 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved top-5 epsilon lower bounds of 1.1175, 1.1125, 1.1118, 1.1073, 1.1070
#
# Best-performing attacks over slice: "CLASS=4"
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved an AUC of 0.53
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved an advantage of 0.16
#   THRESHOLD_ENTROPY_ATTACK (with 5674 training and 1455 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved top-5 epsilon lower bounds of 0.8136, 0.7968, 0.7798, 0.7624, 0.7460
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   THRESHOLD_ENTROPY_ATTACK (with 58500 training and 14538 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 58500 training and 14538 test examples) achieved an advantage of 0.32
#   THRESHOLD_ENTROPY_ATTACK (with 58500 training and 14538 test examples) achieved a positive predictive value of 0.85
#   MULTI_LAYERED_PERCEPTRON (with 58500 training and 14538 test examples) achieved top-5 epsilon lower bounds of 1.2722, 1.2722, 1.2721, 1.2721, 1.2720
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   MULTI_LAYERED_PERCEPTRON (with 21509 training and 5465 test examples) achieved an AUC of 0.52
#   MULTI_LAYERED_PERCEPTRON (with 21509 training and 5465 test examples) achieved an advantage of 0.13
#   MULTI_LAYERED_PERCEPTRON (with 21509 training and 5465 test examples) achieved a positive predictive value of 0.90
#   MULTI_LAYERED_PERCEPTRON (with 21509 training and 5465 test examples) achieved top-5 epsilon lower bounds of 1.2674, 1.2660, 1.2660, 1.2659, 1.2654

# %%
import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
plotting.plot_roc_curve(all_reports[-1].get_result_with_max_auc().roc_curve)
