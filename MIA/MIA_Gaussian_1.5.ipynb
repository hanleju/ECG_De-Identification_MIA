# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4969791805882660173
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14626652160
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12445325526270039998
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
#!pip install tensorflow-privacy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os
import csv
import pywt
from scipy import stats, special
import matplotlib.pyplot as plt

path = ''

import tensorflow as tf

from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import to_categorical

# privacy package
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.optimizers import Adam

# set random seed
import random
random.seed(19122)
from keras.layers import LSTM
# set random seed
np.random.seed(19122)
tf.random.set_seed(19122)

tf.compat.v1.enable_eager_execution()
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackResultsCollection
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyMetric
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyReportMetadata
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import privacy_report

import warnings
warnings.filterwarnings("ignore")

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/RIS/MIT
# Out:
# /content/drive/MyDrive/Colab Notebooks/RIS/MIT

# %% [markdown]
# ## Data

# %%
def denoise(data):
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))

    datarec = pywt.waverec(coeffs, 'sym4')

    return datarec

path = 'mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt
records = list()
annotations = list()
filenames.sort()

# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)

    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
def add_gaussian_noise(signal, noise_std):
    noise = np.random.normal(0, noise_std, len(signal))
    noisy_signal = signal + noise
    return noisy_signal

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1

    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:200])
        plt.show()

    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:200])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:200])
        plt.show()

    origin_signals = signals

    # Add Gaussian noise to the signals
    noise_std = 1.5  # Adjust the noise level as needed
    signals = add_gaussian_noise(signals, noise_std)
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after add gaussian noise ")
        plt.plot(signals[0:200])
        plt.show()

    gaussian_signals = signals

    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines()
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat
                    if r is 1 and not example_beat_printed:
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])

print(np.shape(X))

X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# (100012, 361)
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))

target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))

train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# X_train :  (80009, 361)
# X_test  :  (20003, 361)
# (80009, 5) (20003, 5)
# (80009, 360, 1) (20003, 360, 1)

# %% [markdown]
# ## PrivacyMetric

# %%
class PrivacyMetrics(tf.keras.callbacks.Callback):
  def __init__(self, epochs_per_report, model_name):
    self.epochs_per_report = epochs_per_report
    self.model_name = model_name
    self.attack_results = []

  def on_epoch_end(self, epoch, logs=None):
    epoch = epoch+1

    if epoch % self.epochs_per_report != 0:
      return

    print(f'\nRunning privacy report for epoch: {epoch}\n')

    #print('Predict on train...')
    logits_train = model.predict(train_x, batch_size=batch_size)
    #print('Predict on test...')
    logits_test = model.predict(test_x, batch_size=batch_size)

    #print('Apply softmax to get probabilities from logits...')
    prob_train = tf.nn.softmax(logits_train, axis=-1)
    prob_test = tf.nn.softmax(logits_test)

    #print('Compute losses...')
    cce = tf.keras.backend.categorical_crossentropy
    constant = tf.keras.backend.constant

    y_train_onehot = to_categorical(train_y)
    y_test_onehot = to_categorical(test_y)

    prob_train_onehot = to_categorical(prob_train)
    prob_test_onehot = to_categorical(prob_test)

    loss_train = cce(constant(train_y), constant(prob_train), from_logits=False).numpy()
    loss_test = cce(constant(test_y), constant(prob_test), from_logits=False).numpy()

    print("Add metadata")
    # Add metadata to generate a privacy report.
    privacy_report_metadata = PrivacyReportMetadata(
        # Show the validation accuracy on the plot
        # It's what you send to train_accuracy that gets plotted.
        accuracy_train=logs['val_accuracy'],
        accuracy_test=logs['val_accuracy'],
        epoch_num=epoch,
        model_variant_label=self.model_name)

    #print("Start AttackInputData")
    attack_input = AttackInputData(
      logits_train = logits_train,
      logits_test = logits_test,
      loss_train = loss_train,
      loss_test = loss_test,
      labels_train = np.argmax(train_y, axis=1),
      labels_test = np.argmax(test_y, axis=1)
    )
    #print("Start SlicingSpec")
    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
    by_classification_correctness = True)
    #print("Start attack_types")
    attack_types = [
        AttackType.THRESHOLD_ENTROPY_ATTACK,
        AttackType.MULTI_LAYERED_PERCEPTRON,
    ]
    print("Run MIA Attack")
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                    slicing_spec=slicing_spec,
                                    attack_types=attack_types,
                                    privacy_report_metadata=privacy_report_metadata
                                    )


    self.attack_results.append(attacks_result)

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(LSTM(32, return_sequences=True, activation='tanh', input_shape=(360,1)))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(32,activation='relu'))
model.add(Dense(5,activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'], run_eagerly=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 360, 32)           4352
#
#  lstm_1 (LSTM)               (None, 360, 64)           24832
#
#  lstm_2 (LSTM)               (None, 360, 64)           33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 97477 (380.77 KB)
# Trainable params: 97477 (380.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
epochs_per_report = 1
batch_size = 512
callback = PrivacyMetrics(epochs_per_report, "LSTM")

all_reports = []

history = model.fit(
      train_x,
      train_y,
      batch_size=batch_size,
      epochs=25,
      validation_data=(test_x, test_y),
      callbacks=[callback],
      shuffle=True)

all_reports.extend(callback.attack_results)
# Out:
# Epoch 1/25
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7d929fab5480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7d929fab5480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 157/157 [==============================] - ETA: 0s - loss: 0.9355 - accuracy: 0.7447
# Running privacy report for epoch: 1
#
# 157/157 [==============================] - 7s 42ms/step
# 40/40 [==============================] - 2s 57ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 146s 919ms/step - loss: 0.9355 - accuracy: 0.7447 - val_loss: 0.8918 - val_accuracy: 0.7482
# Epoch 2/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.7565
# Running privacy report for epoch: 2
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 39ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 155s 989ms/step - loss: 0.8415 - accuracy: 0.7565 - val_loss: 0.7244 - val_accuracy: 0.7853
# Epoch 3/25
# 157/157 [==============================] - ETA: 0s - loss: 0.6789 - accuracy: 0.7932
# Running privacy report for epoch: 3
#
# 157/157 [==============================] - 8s 48ms/step
# 40/40 [==============================] - 2s 42ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 165s 1s/step - loss: 0.6789 - accuracy: 0.7932 - val_loss: 0.6270 - val_accuracy: 0.7992
# Epoch 4/25
# 157/157 [==============================] - ETA: 0s - loss: 0.5590 - accuracy: 0.8259
# Running privacy report for epoch: 4
#
# 157/157 [==============================] - 6s 41ms/step
# 40/40 [==============================] - 2s 48ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 178s 1s/step - loss: 0.5590 - accuracy: 0.8259 - val_loss: 0.5099 - val_accuracy: 0.8461
# Epoch 5/25
# 157/157 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.8526
# Running privacy report for epoch: 5
#
# 157/157 [==============================] - 7s 44ms/step
# 40/40 [==============================] - 2s 56ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 175s 1s/step - loss: 0.4867 - accuracy: 0.8526 - val_loss: 0.4756 - val_accuracy: 0.8551
# Epoch 6/25
# 157/157 [==============================] - ETA: 0s - loss: 0.4505 - accuracy: 0.8649
# Running privacy report for epoch: 6
#
# 157/157 [==============================] - 7s 46ms/step
# 40/40 [==============================] - 2s 51ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 180s 1s/step - loss: 0.4505 - accuracy: 0.8649 - val_loss: 0.4683 - val_accuracy: 0.8554
# Epoch 7/25
# 157/157 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8742
# Running privacy report for epoch: 7
#
# 157/157 [==============================] - 9s 60ms/step
# 40/40 [==============================] - 2s 55ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 170s 1s/step - loss: 0.4212 - accuracy: 0.8742 - val_loss: 0.3837 - val_accuracy: 0.8858
# Epoch 8/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.8878
# Running privacy report for epoch: 8
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 55ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 181s 1s/step - loss: 0.3743 - accuracy: 0.8878 - val_loss: 0.3462 - val_accuracy: 0.8937
# Epoch 9/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8976
# Running privacy report for epoch: 9
#
# 157/157 [==============================] - 7s 48ms/step
# 40/40 [==============================] - 2s 43ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 183s 1s/step - loss: 0.3369 - accuracy: 0.8976 - val_loss: 0.3168 - val_accuracy: 0.9017
# Epoch 10/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.9060
# Running privacy report for epoch: 10
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 40ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 186s 1s/step - loss: 0.2996 - accuracy: 0.9060 - val_loss: 0.2828 - val_accuracy: 0.9098
# Epoch 11/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.9102
# Running privacy report for epoch: 11
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 59ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 170s 1s/step - loss: 0.2823 - accuracy: 0.9102 - val_loss: 0.2787 - val_accuracy: 0.9104
# Epoch 12/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.9157
# Running privacy report for epoch: 12
#
# 157/157 [==============================] - 7s 42ms/step
# 40/40 [==============================] - 2s 54ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 187s 1s/step - loss: 0.2635 - accuracy: 0.9157 - val_loss: 0.2508 - val_accuracy: 0.9199
# Epoch 13/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9210
# Running privacy report for epoch: 13
#
# 157/157 [==============================] - 8s 49ms/step
# 40/40 [==============================] - 2s 40ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 181s 1s/step - loss: 0.2462 - accuracy: 0.9210 - val_loss: 0.2490 - val_accuracy: 0.9191
# Epoch 14/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9229
# Running privacy report for epoch: 14
#
# 157/157 [==============================] - 7s 43ms/step
# 40/40 [==============================] - 2s 50ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 187s 1s/step - loss: 0.2389 - accuracy: 0.9229 - val_loss: 0.2415 - val_accuracy: 0.9222
# Epoch 15/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9253
# Running privacy report for epoch: 15
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 42ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 187s 1s/step - loss: 0.2317 - accuracy: 0.9253 - val_loss: 0.2322 - val_accuracy: 0.9260
# Epoch 16/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9273
# Running privacy report for epoch: 16
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 41ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 180s 1s/step - loss: 0.2276 - accuracy: 0.9273 - val_loss: 0.2329 - val_accuracy: 0.9257
# Epoch 17/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 0.9292
# Running privacy report for epoch: 17
#
# 157/157 [==============================] - 7s 42ms/step
# 40/40 [==============================] - 2s 55ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 171s 1s/step - loss: 0.2213 - accuracy: 0.9292 - val_loss: 0.2289 - val_accuracy: 0.9267
# Epoch 18/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.9319
# Running privacy report for epoch: 18
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 56ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 184s 1s/step - loss: 0.2130 - accuracy: 0.9319 - val_loss: 0.2138 - val_accuracy: 0.9314
# Epoch 19/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9326
# Running privacy report for epoch: 19
#
# 157/157 [==============================] - 8s 51ms/step
# 40/40 [==============================] - 2s 41ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 182s 1s/step - loss: 0.2096 - accuracy: 0.9326 - val_loss: 0.2159 - val_accuracy: 0.9305
# Epoch 20/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9344
# Running privacy report for epoch: 20
#
# 157/157 [==============================] - 6s 40ms/step
# 40/40 [==============================] - 2s 40ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 187s 1s/step - loss: 0.2037 - accuracy: 0.9344 - val_loss: 0.2099 - val_accuracy: 0.9320
# Epoch 21/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9353
# Running privacy report for epoch: 21
#
# 157/157 [==============================] - 8s 52ms/step
# 40/40 [==============================] - 2s 41ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 191s 1s/step - loss: 0.2013 - accuracy: 0.9353 - val_loss: 0.2106 - val_accuracy: 0.9326
# Epoch 22/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9377
# Running privacy report for epoch: 22
#
# 157/157 [==============================] - 8s 49ms/step
# 40/40 [==============================] - 2s 45ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 181s 1s/step - loss: 0.1961 - accuracy: 0.9377 - val_loss: 0.2211 - val_accuracy: 0.9290
# Epoch 23/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9372
# Running privacy report for epoch: 23
#
# 157/157 [==============================] - 8s 50ms/step
# 40/40 [==============================] - 2s 42ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 190s 1s/step - loss: 0.1931 - accuracy: 0.9372 - val_loss: 0.2066 - val_accuracy: 0.9329
# Epoch 24/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9398
# Running privacy report for epoch: 24
#
# 157/157 [==============================] - 8s 51ms/step
# 40/40 [==============================] - 2s 42ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 187s 1s/step - loss: 0.1882 - accuracy: 0.9398 - val_loss: 0.1980 - val_accuracy: 0.9379
# Epoch 25/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9404
# Running privacy report for epoch: 25
#
# 157/157 [==============================] - 6s 41ms/step
# 40/40 [==============================] - 2s 43ms/step
# Add metadata
# Run MIA Attack
# 157/157 [==============================] - 190s 1s/step - loss: 0.1856 - accuracy: 0.9404 - val_loss: 0.2048 - val_accuracy: 0.9354

# %%
results = AttackResultsCollection(all_reports)

# %% [markdown]
# ## Evaluate

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
epoch_plot = privacy_report.plot_by_epochs(
    results, privacy_metrics=privacy_metrics)

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
utility_privacy_plot = privacy_report.plot_privacy_vs_accuracy(
    results, privacy_metrics=privacy_metrics)

for axis in utility_privacy_plot.axes:
  axis.set_xlabel('Validation accuracy')

# %% [markdown]
# ## Evaluate2

# %%
print(all_reports[-1].summary(by_slices=True))
# Out:
# Best-performing attacks over all slices
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an AUC of 0.61 on slice Entire dataset
#   MULTI_LAYERED_PERCEPTRON (with 60044 training and 14967 test examples) achieved an advantage of 0.37 on slice CLASS=0
#   THRESHOLD_ENTROPY_ATTACK (with 6493 training and 1578 test examples) achieved a positive predictive value of 1.00 on slice CLASS=1
#   MULTI_LAYERED_PERCEPTRON (with 5791 training and 1464 test examples) achieved top-5 epsilon lower bounds of 1.4017, 1.3990, 1.3978, 1.3901, 1.3892 on slice CLASS=2
#
# Best-performing attacks over slice: "Entire dataset"
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an AUC of 0.61
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an advantage of 0.27
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved top-5 epsilon lower bounds of 0.7530, 0.7529, 0.7529, 0.7529, 0.7529
#
# Best-performing attacks over slice: "CLASS=0"
#   THRESHOLD_ENTROPY_ATTACK (with 60044 training and 14967 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 60044 training and 14967 test examples) achieved an advantage of 0.37
#   THRESHOLD_ENTROPY_ATTACK (with 60044 training and 14967 test examples) achieved a positive predictive value of 0.84
#   MULTI_LAYERED_PERCEPTRON (with 60044 training and 14967 test examples) achieved top-5 epsilon lower bounds of 1.3653, 1.3653, 1.3653, 1.3653, 1.3653
#
# Best-performing attacks over slice: "CLASS=1"
#   THRESHOLD_ENTROPY_ATTACK (with 6493 training and 1578 test examples) achieved an AUC of 0.51
#   MULTI_LAYERED_PERCEPTRON (with 6493 training and 1578 test examples) achieved an advantage of 0.14
#   THRESHOLD_ENTROPY_ATTACK (with 6493 training and 1578 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 6493 training and 1578 test examples) achieved top-5 epsilon lower bounds of 1.2133, 1.2117, 1.2108, 1.2103, 1.2098
#
# Best-performing attacks over slice: "CLASS=2"
#   THRESHOLD_ENTROPY_ATTACK (with 5791 training and 1464 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 5791 training and 1464 test examples) achieved an advantage of 0.21
#   THRESHOLD_ENTROPY_ATTACK (with 5791 training and 1464 test examples) achieved a positive predictive value of 0.84
#   MULTI_LAYERED_PERCEPTRON (with 5791 training and 1464 test examples) achieved top-5 epsilon lower bounds of 1.4017, 1.3990, 1.3978, 1.3901, 1.3892
#
# Best-performing attacks over slice: "CLASS=3"
#   THRESHOLD_ENTROPY_ATTACK (with 2027 training and 519 test examples) achieved an AUC of 0.52
#   MULTI_LAYERED_PERCEPTRON (with 2027 training and 519 test examples) achieved an advantage of 0.27
#   THRESHOLD_ENTROPY_ATTACK (with 2027 training and 519 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 2027 training and 519 test examples) achieved top-5 epsilon lower bounds of 1.4061, 1.3989, 1.3877, 1.3794, 1.3738
#
# Best-performing attacks over slice: "CLASS=4"
#   THRESHOLD_ENTROPY_ATTACK (with 5654 training and 1475 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 5654 training and 1475 test examples) achieved an advantage of 0.19
#   THRESHOLD_ENTROPY_ATTACK (with 5654 training and 1475 test examples) achieved a positive predictive value of 0.93
#   THRESHOLD_ENTROPY_ATTACK (with 5654 training and 1475 test examples) achieved top-5 epsilon lower bounds of 1.0973, 0.7887, 0.7177, 0.7000, 0.6901
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   THRESHOLD_ENTROPY_ATTACK (with 75389 training and 18711 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 75389 training and 18711 test examples) achieved an advantage of 0.24
#   MULTI_LAYERED_PERCEPTRON (with 75389 training and 18711 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 75389 training and 18711 test examples) achieved top-5 epsilon lower bounds of 1.2816, 1.2799, 1.2798, 1.2796, 1.2780
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   THRESHOLD_ENTROPY_ATTACK (with 4620 training and 1292 test examples) achieved an AUC of 0.52
#   MULTI_LAYERED_PERCEPTRON (with 4620 training and 1292 test examples) achieved an advantage of 0.08
#   MULTI_LAYERED_PERCEPTRON (with 4620 training and 1292 test examples) achieved a positive predictive value of 0.84
#   MULTI_LAYERED_PERCEPTRON (with 4620 training and 1292 test examples) achieved top-5 epsilon lower bounds of 1.1277, 1.0279, 0.9951, 0.9830, 0.9503

# %%
import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
plotting.plot_roc_curve(all_reports[-1].get_result_with_max_auc().roc_curve)
