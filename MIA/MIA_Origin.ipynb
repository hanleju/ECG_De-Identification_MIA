# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 430571507459647062
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14626652160
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11091495806956578837
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !pip install tensorflow-privacy
# Out:
# Collecting tensorflow-privacy
#   Downloading tensorflow_privacy-0.8.12-py3-none-any.whl (405 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.5/405.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py==1.*,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (1.4.0)
# Requirement already satisfied: attrs>=21.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (23.1.0)
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (0.1.8)
# Collecting dp-accounting==0.4.3 (from tensorflow-privacy)
#   Downloading dp_accounting-0.4.3-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 6.0 MB/s eta 0:00:00
# Collecting immutabledict~=2.2 (from tensorflow-privacy)
#   Downloading immutabledict-2.2.5-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: matplotlib~=3.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (3.7.1)
# Requirement already satisfied: numpy~=1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (1.23.5)
# Collecting packaging~=22.0 (from tensorflow-privacy)
#   Downloading packaging-22.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas~=1.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (1.5.3)
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (1.2.2)
# Requirement already satisfied: scipy~=1.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (1.11.4)
# Requirement already satisfied: statsmodels~=0.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (0.14.1)
# Requirement already satisfied: tensorflow-estimator~=2.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (2.15.0)
# Requirement already satisfied: tensorflow-probability~=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (0.22.0)
# Requirement already satisfied: tensorflow~=2.4 in /usr/local/lib/python3.10/dist-packages (from tensorflow-privacy) (2.15.0)
# Collecting tf-models-official~=2.13 (from tensorflow-privacy)
#   Downloading tf_models_official-2.15.0-py2.py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath~=1.2 in /usr/local/lib/python3.10/dist-packages (from dp-accounting==0.4.3->tensorflow-privacy) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.3->tensorflow-privacy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.4->tensorflow-privacy) (2023.3.post1)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels~=0.13->tensorflow-privacy) (0.5.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (2.15.1)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.4->tensorflow-privacy) (2.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy) (2.2.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (3.0.6)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (2.84.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (1.5.16)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (4.8.1.78)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (9.0.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (2.0.7)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (6.0.1)
# Collecting sacrebleu (from tf-models-official~=2.13->tensorflow-privacy)
#   Downloading sacrebleu-2.4.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 9.7 MB/s eta 0:00:00
# Collecting sentencepiece (from tf-models-official~=2.13->tensorflow-privacy)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official~=2.13->tensorflow-privacy)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (4.9.4)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (0.15.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official~=2.13->tensorflow-privacy)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 18.4 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.15.0 (from tf-models-official~=2.13->tensorflow-privacy)
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official~=2.13->tensorflow-privacy) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.4->tensorflow-privacy) (0.42.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (4.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (2023.11.17)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (6.1.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (3.0.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official~=2.13->tensorflow-privacy) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official~=2.13->tensorflow-privacy) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official~=2.13->tensorflow-privacy) (4.9)
# Collecting portalocker (from sacrebleu->tf-models-official~=2.13->tensorflow-privacy)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official~=2.13->tensorflow-privacy) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official~=2.13->tensorflow-privacy) (0.9.0)
# Collecting colorama (from sacrebleu->tf-models-official~=2.13->tensorflow-privacy)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official~=2.13->tensorflow-privacy) (4.9.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (1.6.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (1.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (0.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (6.1.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official~=2.13->tensorflow-privacy) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official~=2.13->tensorflow-privacy) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (3.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (2.1.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official~=2.13->tensorflow-privacy) (1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.4->tensorflow-privacy) (3.2.2)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=364154d1d0acc0f1f2fe2316ac7e72a1b7f6a9f186fe28171cde30faf188dbda
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: sentencepiece, tensorflow-model-optimization, portalocker, packaging, immutabledict, colorama, sacrebleu, dp-accounting, seqeval, tensorflow-text, tf-models-official, tensorflow-privacy
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed colorama-0.4.6 dp-accounting-0.4.3 immutabledict-2.2.5 packaging-22.0 portalocker-2.8.2 sacrebleu-2.4.0 sentencepiece-0.1.99 seqeval-1.2.2 tensorflow-model-optimization-0.7.5 tensorflow-privacy-0.8.12 tensorflow-text-2.15.0 tf-models-official-2.15.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import csv
import pywt
from scipy import stats, special
import matplotlib.pyplot as plt

path = ''

import tensorflow as tf

from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import to_categorical

# privacy package
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.optimizers import Adam

# set random seed
import random
random.seed(19122)
# set random seed
np.random.seed(19122)
tf.random.set_seed(19122)

tf.compat.v1.enable_eager_execution()
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackResultsCollection
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyMetric
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import PrivacyReportMetadata
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import privacy_report

import warnings
warnings.filterwarnings("ignore")

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/RIS/MIT
# Out:
# /content/drive/MyDrive/Colab Notebooks/RIS/MIT

# %% [markdown]
# ## Data

# %%
def denoise(data):
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))

    datarec = pywt.waverec(coeffs, 'sym4')

    return datarec

path = 'mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt
records = list()
annotations = list()
filenames.sort()

# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)

    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1

    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:700])
        plt.show()

    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()

    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()

    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines()
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat
                    if r is 1 and not example_beat_printed:
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])

print(np.shape(X))

X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# (100012, 361)
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %%
train, test = train_test_split(X_train_df, test_size=0.20)

print("X_train : ", np.shape(train))
print("X_test  : ", np.shape(test))

target_train=train[train.shape[1]-1]
target_test=test[test.shape[1]-1]
train_y=to_categorical(target_train)
test_y=to_categorical(target_test)
print(np.shape(train_y), np.shape(test_y))

train_x = train.iloc[:,:train.shape[1]-1].values
test_x = test.iloc[:,:test.shape[1]-1].values
train_x = train_x.reshape(len(train_x), train_x.shape[1],1)
test_x = test_x.reshape(len(test_x), test_x.shape[1],1)
print(np.shape(train_x), np.shape(test_x))
# Out:
# X_train :  (80009, 361)
# X_test  :  (20003, 361)
# (80009, 5) (20003, 5)
# (80009, 360, 1) (20003, 360, 1)

# %% [markdown]
# ## PrivacyMetric

# %%
class PrivacyMetrics(tf.keras.callbacks.Callback):
  def __init__(self, epochs_per_report, model_name):
    self.epochs_per_report = epochs_per_report
    self.model_name = model_name
    self.attack_results = []

  def on_epoch_end(self, epoch, logs=None):
    epoch = epoch+1

    if epoch % self.epochs_per_report != 0:
      return

    print(f'\nRunning privacy report for epoch: {epoch}\n')

    print('Predict on train...')
    logits_train = model.predict(train_x, batch_size=batch_size)
    print('Predict on test...')
    logits_test = model.predict(test_x, batch_size=batch_size)

    print('Apply softmax to get probabilities from logits...')
    prob_train = tf.nn.softmax(logits_train, axis=-1)
    prob_test = tf.nn.softmax(logits_test)

    print('Compute losses...')
    cce = tf.keras.backend.categorical_crossentropy
    constant = tf.keras.backend.constant

    y_train_onehot = to_categorical(train_y)
    y_test_onehot = to_categorical(test_y)

    prob_train_onehot = to_categorical(prob_train)
    prob_test_onehot = to_categorical(prob_test)

    loss_train = cce(constant(train_y), constant(prob_train), from_logits=False).numpy()
    loss_test = cce(constant(test_y), constant(prob_test), from_logits=False).numpy()

    print("Add metadata")
    # Add metadata to generate a privacy report.
    privacy_report_metadata = PrivacyReportMetadata(
        # Show the validation accuracy on the plot
        # It's what you send to train_accuracy that gets plotted.
        accuracy_train=logs['val_accuracy'],
        accuracy_test=logs['val_accuracy'],
        epoch_num=epoch,
        model_variant_label=self.model_name)

    print("Start AttackInputData")
    attack_input = AttackInputData(
      logits_train = logits_train,
      logits_test = logits_test,
      loss_train = loss_train,
      loss_test = loss_test,
      labels_train = np.argmax(train_y, axis=1),
      labels_test = np.argmax(test_y, axis=1)
    )
    print("Start SlicingSpec")
    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
    by_classification_correctness = True)
    print("Start attack_types")
    attack_types = [
        AttackType.THRESHOLD_ENTROPY_ATTACK,
        AttackType.MULTI_LAYERED_PERCEPTRON,
    ]
    print("Start Run Attacks")
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                    slicing_spec=slicing_spec,
                                    attack_types=attack_types,
                                    privacy_report_metadata=privacy_report_metadata
                                    )
    self.attack_results.append(attacks_result)

# %% [markdown]
# ## Model

# %%
model = Sequential()

model.add(LSTM(32, return_sequences=True, activation='tanh', input_shape=(360,1)))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(32,activation='relu'))
model.add(Dense(5,activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'], run_eagerly=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 360, 32)           4352
#
#  lstm_1 (LSTM)               (None, 360, 64)           24832
#
#  lstm_2 (LSTM)               (None, 360, 64)           33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 97477 (380.77 KB)
# Trainable params: 97477 (380.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
epochs_per_report = 1
batch_size = 512
callback = PrivacyMetrics(epochs_per_report, "LSTM")

all_reports = []

history = model.fit(
      train_x,
      train_y,
      batch_size=batch_size,
      epochs=25,
      validation_data=(test_x, test_y),
      callbacks=[callback],
      shuffle=True)

all_reports.extend(callback.attack_results)
# Out:
# Epoch 1/25
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7de59c609120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7de59c609120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 157/157 [==============================] - ETA: 0s - loss: 0.9334 - accuracy: 0.7456
# Running privacy report for epoch: 1
#
# Predict on train...
# 157/157 [==============================] - 7s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 143s 881ms/step - loss: 0.9334 - accuracy: 0.7456 - val_loss: 0.9104 - val_accuracy: 0.7433
# Epoch 2/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8837 - accuracy: 0.7517
# Running privacy report for epoch: 2
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 140s 897ms/step - loss: 0.8837 - accuracy: 0.7517 - val_loss: 0.8970 - val_accuracy: 0.7433
# Epoch 3/25
# 157/157 [==============================] - ETA: 0s - loss: 0.8679 - accuracy: 0.7517
# Running privacy report for epoch: 3
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 157s 1s/step - loss: 0.8679 - accuracy: 0.7517 - val_loss: 0.8884 - val_accuracy: 0.7432
# Epoch 4/25
# 157/157 [==============================] - ETA: 0s - loss: 0.7414 - accuracy: 0.7725
# Running privacy report for epoch: 4
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 149s 953ms/step - loss: 0.7414 - accuracy: 0.7725 - val_loss: 0.5624 - val_accuracy: 0.8110
# Epoch 5/25
# 157/157 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8725
# Running privacy report for epoch: 5
#
# Predict on train...
# 157/157 [==============================] - 7s 43ms/step
# Predict on test...
# 40/40 [==============================] - 2s 54ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 156s 999ms/step - loss: 0.4217 - accuracy: 0.8725 - val_loss: 0.4037 - val_accuracy: 0.8765
# Epoch 6/25
# 157/157 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.9090
# Running privacy report for epoch: 6
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 49ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 156s 996ms/step - loss: 0.3243 - accuracy: 0.9090 - val_loss: 0.3226 - val_accuracy: 0.9121
# Epoch 7/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9219
# Running privacy report for epoch: 7
#
# Predict on train...
# 157/157 [==============================] - 7s 46ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 170s 1s/step - loss: 0.2867 - accuracy: 0.9219 - val_loss: 0.2872 - val_accuracy: 0.9249
# Epoch 8/25
# 157/157 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9391
# Running privacy report for epoch: 8
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 167s 1s/step - loss: 0.2258 - accuracy: 0.9391 - val_loss: 0.2247 - val_accuracy: 0.9394
# Epoch 9/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9469
# Running privacy report for epoch: 9
#
# Predict on train...
# 157/157 [==============================] - 7s 46ms/step
# Predict on test...
# 40/40 [==============================] - 2s 44ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 158s 1s/step - loss: 0.1979 - accuracy: 0.9469 - val_loss: 0.1943 - val_accuracy: 0.9470
# Epoch 10/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9495
# Running privacy report for epoch: 10
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 162s 1s/step - loss: 0.1861 - accuracy: 0.9495 - val_loss: 0.1673 - val_accuracy: 0.9574
# Epoch 11/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.9593
# Running privacy report for epoch: 11
#
# Predict on train...
# 157/157 [==============================] - 6s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 48ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 157s 1s/step - loss: 0.1498 - accuracy: 0.9593 - val_loss: 0.1497 - val_accuracy: 0.9602
# Epoch 12/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9643
# Running privacy report for epoch: 12
#
# Predict on train...
# 157/157 [==============================] - 6s 40ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 160s 1s/step - loss: 0.1282 - accuracy: 0.9643 - val_loss: 0.1314 - val_accuracy: 0.9636
# Epoch 13/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9678
# Running privacy report for epoch: 13
#
# Predict on train...
# 157/157 [==============================] - 7s 47ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 158s 1s/step - loss: 0.1132 - accuracy: 0.9678 - val_loss: 0.1163 - val_accuracy: 0.9699
# Epoch 14/25
# 157/157 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9716
# Running privacy report for epoch: 14
#
# Predict on train...
# 157/157 [==============================] - 6s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 153s 977ms/step - loss: 0.1022 - accuracy: 0.9716 - val_loss: 0.1180 - val_accuracy: 0.9683
# Epoch 15/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9732
# Running privacy report for epoch: 15
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 159s 1s/step - loss: 0.0967 - accuracy: 0.9732 - val_loss: 0.0983 - val_accuracy: 0.9743
# Epoch 16/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9750
# Running privacy report for epoch: 16
#
# Predict on train...
# 157/157 [==============================] - 6s 40ms/step
# Predict on test...
# 40/40 [==============================] - 2s 56ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 160s 1s/step - loss: 0.0890 - accuracy: 0.9750 - val_loss: 0.1046 - val_accuracy: 0.9712
# Epoch 17/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9771
# Running privacy report for epoch: 17
#
# Predict on train...
# 157/157 [==============================] - 8s 48ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 161s 1s/step - loss: 0.0824 - accuracy: 0.9771 - val_loss: 0.0908 - val_accuracy: 0.9778
# Epoch 18/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9777
# Running privacy report for epoch: 18
#
# Predict on train...
# 157/157 [==============================] - 7s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 156s 1s/step - loss: 0.0801 - accuracy: 0.9777 - val_loss: 0.0907 - val_accuracy: 0.9762
# Epoch 19/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9796
# Running privacy report for epoch: 19
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 159s 1s/step - loss: 0.0734 - accuracy: 0.9796 - val_loss: 0.0901 - val_accuracy: 0.9762
# Epoch 20/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9801
# Running privacy report for epoch: 20
#
# Predict on train...
# 157/157 [==============================] - 6s 41ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 156s 997ms/step - loss: 0.0709 - accuracy: 0.9801 - val_loss: 0.0816 - val_accuracy: 0.9789
# Epoch 21/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9817
# Running privacy report for epoch: 21
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 51ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 157s 1s/step - loss: 0.0650 - accuracy: 0.9817 - val_loss: 0.0912 - val_accuracy: 0.9757
# Epoch 22/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9819
# Running privacy report for epoch: 22
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 40ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 155s 991ms/step - loss: 0.0652 - accuracy: 0.9819 - val_loss: 0.0793 - val_accuracy: 0.9790
# Epoch 23/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9826
# Running privacy report for epoch: 23
#
# Predict on train...
# 157/157 [==============================] - 7s 45ms/step
# Predict on test...
# 40/40 [==============================] - 2s 43ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 158s 1s/step - loss: 0.0618 - accuracy: 0.9826 - val_loss: 0.0827 - val_accuracy: 0.9794
# Epoch 24/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9834
# Running privacy report for epoch: 24
#
# Predict on train...
# 157/157 [==============================] - 8s 50ms/step
# Predict on test...
# 40/40 [==============================] - 2s 42ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 156s 1000ms/step - loss: 0.0588 - accuracy: 0.9834 - val_loss: 0.0757 - val_accuracy: 0.9791
# Epoch 25/25
# 157/157 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9845
# Running privacy report for epoch: 25
#
# Predict on train...
# 157/157 [==============================] - 8s 49ms/step
# Predict on test...
# 40/40 [==============================] - 2s 41ms/step
# Apply softmax to get probabilities from logits...
# Compute losses...
# Add metadata
# Start AttackInputData
# Start SlicingSpec
# Start attack_types
# Start Run Attacks
# 157/157 [==============================] - 151s 970ms/step - loss: 0.0548 - accuracy: 0.9845 - val_loss: 0.0708 - val_accuracy: 0.9817

# %%
results = AttackResultsCollection(all_reports)

# %% [markdown]
# ## Evaluate

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
epoch_plot = privacy_report.plot_by_epochs(
    results, privacy_metrics=privacy_metrics)

# %%
privacy_metrics = (PrivacyMetric.AUC, PrivacyMetric.ATTACKER_ADVANTAGE)
utility_privacy_plot = privacy_report.plot_privacy_vs_accuracy(
    results, privacy_metrics=privacy_metrics)

for axis in utility_privacy_plot.axes:
  axis.set_xlabel('Validation accuracy')

# %% [markdown]
# ## Evaluate2

# %%
print(all_reports[-1].summary(by_slices=True))
# Out:
# Best-performing attacks over all slices
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an AUC of 0.68 on slice Entire dataset
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an advantage of 0.37 on slice Entire dataset
#   MULTI_LAYERED_PERCEPTRON (with 1213 training and 367 test examples) achieved a positive predictive value of 1.00 on slice CORRECTLY_CLASSIFIED=False
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved top-5 epsilon lower bounds of 1.7686, 1.6837, 1.6162, 1.6031, 1.5912 on slice CLASS=2
#
# Best-performing attacks over slice: "Entire dataset"
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an AUC of 0.68
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved an advantage of 0.37
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved a positive predictive value of 0.91
#   MULTI_LAYERED_PERCEPTRON (with 80009 training and 20003 test examples) achieved top-5 epsilon lower bounds of 1.7308, 1.6831, 1.6024, 1.5912, 1.5906
#
# Best-performing attacks over slice: "CLASS=0"
#   THRESHOLD_ENTROPY_ATTACK (with 60143 training and 14868 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved an advantage of 0.36
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 60143 training and 14868 test examples) achieved top-5 epsilon lower bounds of 1.6641, 1.4386, 1.3414, 1.3412, 1.3411
#
# Best-performing attacks over slice: "CLASS=1"
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an AUC of 0.67
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved an advantage of 0.36
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved a positive predictive value of 0.87
#   MULTI_LAYERED_PERCEPTRON (with 6397 training and 1674 test examples) achieved top-5 epsilon lower bounds of 1.1943, 1.1941, 1.1935, 1.1934, 1.1931
#
# Best-performing attacks over slice: "CLASS=2"
#   THRESHOLD_ENTROPY_ATTACK (with 5803 training and 1452 test examples) achieved an AUC of 0.51
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved an advantage of 0.36
#   THRESHOLD_ENTROPY_ATTACK (with 5803 training and 1452 test examples) achieved a positive predictive value of 0.84
#   MULTI_LAYERED_PERCEPTRON (with 5803 training and 1452 test examples) achieved top-5 epsilon lower bounds of 1.7686, 1.6837, 1.6162, 1.6031, 1.5912
#
# Best-performing attacks over slice: "CLASS=3"
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved an AUC of 0.58
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved an advantage of 0.22
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved a positive predictive value of 0.86
#   MULTI_LAYERED_PERCEPTRON (with 1992 training and 554 test examples) achieved top-5 epsilon lower bounds of 0.6376, 0.6140, 0.6006, 0.4354, 0.4342
#
# Best-performing attacks over slice: "CLASS=4"
#   THRESHOLD_ENTROPY_ATTACK (with 5674 training and 1455 test examples) achieved an AUC of 0.50
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved an advantage of 0.33
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved a positive predictive value of 0.88
#   MULTI_LAYERED_PERCEPTRON (with 5674 training and 1455 test examples) achieved top-5 epsilon lower bounds of 1.0304, 1.0295, 1.0293, 1.0291, 1.0288
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=True"
#   MULTI_LAYERED_PERCEPTRON (with 78796 training and 19636 test examples) achieved an AUC of 0.64
#   MULTI_LAYERED_PERCEPTRON (with 78796 training and 19636 test examples) achieved an advantage of 0.29
#   MULTI_LAYERED_PERCEPTRON (with 78796 training and 19636 test examples) achieved a positive predictive value of 0.93
#   MULTI_LAYERED_PERCEPTRON (with 78796 training and 19636 test examples) achieved top-5 epsilon lower bounds of 1.1645, 1.1074, 0.9822, 0.9132, 0.9031
#
# Best-performing attacks over slice: "CORRECTLY_CLASSIFIED=False"
#   THRESHOLD_ENTROPY_ATTACK (with 1213 training and 367 test examples) achieved an AUC of 0.55
#   MULTI_LAYERED_PERCEPTRON (with 1213 training and 367 test examples) achieved an advantage of 0.14
#   MULTI_LAYERED_PERCEPTRON (with 1213 training and 367 test examples) achieved a positive predictive value of 1.00
#   MULTI_LAYERED_PERCEPTRON (with 1213 training and 367 test examples) achieved top-5 epsilon lower bounds of 0.5252, 0.4793, 0.4557, 0.4275, 0.4189

# %%
import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
plotting.plot_roc_curve(all_reports[-1].get_result_with_max_auc().roc_curve)
